# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import math
from sklearn import linear_model

# %%
df=pd.read_csv('bike share/train.csv')
trainFrame=df
trainFrame['logc']=trainFrame['count'].apply(lambda x: math.log(x+1.0))
trainFrame.datetime=trainFrame.datetime.apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
trainFrame['logtimescale']=trainFrame.datetime.apply(lambda x: math.log((x-datetime.datetime(2010,12,31,23,0,0)).total_seconds()))
trainFrame=trainFrame.set_index('datetime')

# %%
testFrame=trainFrame
testFrame['temp2']= testFrame.temp**2
testFrame['atemp2'] = testFrame.atemp**2
testFrame['winds2'] =testFrame.windspeed**2
testFrame['hour'] = testFrame.index.hour
testFrame['month'] = testFrame.index.month
testFrame['year'] = testFrame.index.year
testFrame['hum2']=testFrame.humidity**2
testFrame['winter']=testFrame.season.apply(lambda x: 1 if x==1 else 0)
testFrame['spring']=testFrame.season.apply(lambda x: 1 if x==2 else 0)
testFrame['summer']=testFrame.season.apply(lambda x: 1 if x==3 else 0)
testFrame['fall']=testFrame.season.apply(lambda x: 1 if x==4 else 0)
testFrame['dry']=testFrame.weather.apply(lambda x: 1 if x==1 else 0)
testFrame['wet']=testFrame.weather.apply(lambda x: 1 if x==2 else 0)
testFrame['vwet']=testFrame.weather.apply(lambda x: 1 if x==3 else 0)
testFrame['jan1']=testFrame.apply(lambda x: 1 if x.month==1 and x.year==2011 else 0, axis=1)
testFrame['feb1']=testFrame.apply(lambda x: 1 if x.month==2 and x.year==2011 else 0, axis=1)
testFrame['mar1']=testFrame.apply(lambda x: 1 if x.month==3 and x.year==2011 else 0, axis=1)
testFrame['apr1']=testFrame.apply(lambda x: 1 if x.month==4 and x.year==2011 else 0, axis=1)
testFrame['may1']=testFrame.apply(lambda x: 1 if x.month==5 and x.year==2011 else 0, axis=1)
testFrame['jun1']=testFrame.apply(lambda x: 1 if x.month==6 and x.year==2011 else 0, axis=1)
testFrame['jul1']=testFrame.apply(lambda x: 1 if x.month==7 and x.year==2011 else 0, axis=1)
testFrame['aug1']=testFrame.apply(lambda x: 1 if x.month==8 and x.year==2011 else 0, axis=1)
testFrame['sep1']=testFrame.apply(lambda x: 1 if x.month==9 and x.year==2011 else 0, axis=1)
testFrame['oct1']=testFrame.apply(lambda x: 1 if x.month==10 and x.year==2011 else 0, axis=1)
testFrame['nov1']=testFrame.apply(lambda x: 1 if x.month==11 and x.year==2011 else 0, axis=1)
testFrame['dec1']=testFrame.apply(lambda x: 1 if x.month==12 and x.year==2011 else 0, axis=1)
testFrame['jan2']=testFrame.apply(lambda x: 1 if x.month==1 and x.year==2012 else 0, axis=1)
testFrame['feb2']=testFrame.apply(lambda x: 1 if x.month==2 and x.year==2012 else 0, axis=1)
testFrame['mar2']=testFrame.apply(lambda x: 1 if x.month==3 and x.year==2012 else 0, axis=1)
testFrame['apr2']=testFrame.apply(lambda x: 1 if x.month==4 and x.year==2012 else 0, axis=1)
testFrame['may2']=testFrame.apply(lambda x: 1 if x.month==5 and x.year==2012 else 0, axis=1)
testFrame['jun2']=testFrame.apply(lambda x: 1 if x.month==6 and x.year==2012 else 0, axis=1)
testFrame['jul2']=testFrame.apply(lambda x: 1 if x.month==7 and x.year==2012 else 0, axis=1)
testFrame['aug2']=testFrame.apply(lambda x: 1 if x.month==8 and x.year==2012 else 0, axis=1)
testFrame['sep2']=testFrame.apply(lambda x: 1 if x.month==9 and x.year==2012 else 0, axis=1)
testFrame['oct2']=testFrame.apply(lambda x: 1 if x.month==10 and x.year==2012 else 0, axis=1)
testFrame['nov2']=testFrame.apply(lambda x: 1 if x.month==11 and x.year==2012 else 0, axis=1)
testFrame['dec2']=testFrame.apply(lambda x: 1 if x.month==12 and x.year==2012 else 0, axis=1)
testFrame['logcasual']=testFrame['casual'].apply(lambda x: math.log(x+1.0))
testFrame['logrgstr']=testFrame['registered'].apply(lambda x: math.log(x+1.0))
testFrame['djan1']=testFrame['jan1']*testFrame['dry']
testFrame['dfeb1']=testFrame['feb1']*testFrame['dry']
testFrame['dmar1']=testFrame['mar1']*testFrame['dry']
testFrame['dapr1']=testFrame['apr1']*testFrame['dry']
testFrame['dmay1']=testFrame['may1']*testFrame['dry']
testFrame['djun1']=testFrame['jun1']*testFrame['dry']
testFrame['djul1']=testFrame['jul1']*testFrame['dry']
testFrame['daug1']=testFrame['aug1']*testFrame['dry']
testFrame['dsep1']=testFrame['sep1']*testFrame['dry']
testFrame['doct1']=testFrame['oct1']*testFrame['dry']
testFrame['dnov1']=testFrame['nov1']*testFrame['dry']
testFrame['ddec1']=testFrame['dec1']*testFrame['dry']
testFrame['djan2']=testFrame['jan2']*testFrame['dry']
testFrame['dfeb2']=testFrame['feb2']*testFrame['dry']
testFrame['dmar2']=testFrame['mar2']*testFrame['dry']
testFrame['dapr2']=testFrame['apr2']*testFrame['dry']
testFrame['dmay2']=testFrame['may2']*testFrame['dry']
testFrame['djun2']=testFrame['jun2']*testFrame['dry']
testFrame['djul2']=testFrame['jul2']*testFrame['dry']
testFrame['daug2']=testFrame['aug2']*testFrame['dry']
testFrame['dsep2']=testFrame['sep2']*testFrame['dry']
testFrame['doct2']=testFrame['oct2']*testFrame['dry']
testFrame['dnov2']=testFrame['nov2']*testFrame['dry']
testFrame['ddec2']=testFrame['dec2']*testFrame['dry']
testFrame['wjan1']=testFrame['jan1']*testFrame['wet']
testFrame['wfeb1']=testFrame['feb1']*testFrame['wet']
testFrame['wmar1']=testFrame['mar1']*testFrame['wet']
testFrame['wapr1']=testFrame['apr1']*testFrame['wet']
testFrame['wmay1']=testFrame['may1']*testFrame['wet']
testFrame['wjun1']=testFrame['jun1']*testFrame['wet']
testFrame['wjul1']=testFrame['jul1']*testFrame['wet']
testFrame['waug1']=testFrame['aug1']*testFrame['wet']
testFrame['wsep1']=testFrame['sep1']*testFrame['wet']
testFrame['woct1']=testFrame['oct1']*testFrame['wet']
testFrame['wnov1']=testFrame['nov1']*testFrame['wet']
testFrame['wdec1']=testFrame['dec1']*testFrame['wet']
testFrame['wjan2']=testFrame['jan2']*testFrame['wet']
testFrame['wfeb2']=testFrame['feb2']*testFrame['wet']
testFrame['wmar2']=testFrame['mar2']*testFrame['wet']
testFrame['wapr2']=testFrame['apr2']*testFrame['wet']
testFrame['wmay2']=testFrame['may2']*testFrame['wet']
testFrame['wjun2']=testFrame['jun2']*testFrame['wet']
testFrame['wjul2']=testFrame['jul2']*testFrame['wet']
testFrame['waug2']=testFrame['aug2']*testFrame['wet']
testFrame['wsep2']=testFrame['sep2']*testFrame['wet']
testFrame['woct2']=testFrame['oct2']*testFrame['wet']
testFrame['wnov2']=testFrame['nov2']*testFrame['wet']
testFrame['wdec2']=testFrame['dec2']*testFrame['wet']
testFrame['vjan1']=testFrame['jan1']*testFrame['vwet']
testFrame['vfeb1']=testFrame['feb1']*testFrame['vwet']
testFrame['vmar1']=testFrame['mar1']*testFrame['vwet']
testFrame['vapr1']=testFrame['apr1']*testFrame['vwet']
testFrame['vmay1']=testFrame['may1']*testFrame['vwet']
testFrame['vjun1']=testFrame['jun1']*testFrame['vwet']
testFrame['vjul1']=testFrame['jul1']*testFrame['vwet']
testFrame['vaug1']=testFrame['aug1']*testFrame['vwet']
testFrame['vsep1']=testFrame['sep1']*testFrame['vwet']
testFrame['voct1']=testFrame['oct1']*testFrame['vwet']
testFrame['vnov1']=testFrame['nov1']*testFrame['vwet']
testFrame['vdec1']=testFrame['dec1']*testFrame['vwet']
testFrame['vjan2']=testFrame['jan2']*testFrame['vwet']
testFrame['vfeb2']=testFrame['feb2']*testFrame['vwet']
testFrame['vmar2']=testFrame['mar2']*testFrame['vwet']
testFrame['vapr2']=testFrame['apr2']*testFrame['vwet']
testFrame['vmay2']=testFrame['may2']*testFrame['vwet']
testFrame['vjun2']=testFrame['jun2']*testFrame['vwet']
testFrame['vjul2']=testFrame['jul2']*testFrame['vwet']
testFrame['vaug2']=testFrame['aug2']*testFrame['vwet']
testFrame['vsep2']=testFrame['sep2']*testFrame['vwet']
testFrame['voct2']=testFrame['oct2']*testFrame['vwet']
testFrame['vnov2']=testFrame['nov2']*testFrame['vwet']
testFrame['vdec2']=testFrame['dec2']*testFrame['vwet']
testFrame['wt']=testFrame.winter*testFrame.atemp
testFrame['spt']=testFrame.spring*testFrame.atemp
testFrame['sut']=testFrame.summer*testFrame.atemp
testFrame['ft']=testFrame.fall*testFrame.atemp
testFrame['logtimescale2']=testFrame.logtimescale**2
seasons=['spring','summer','winter','fall']
seasonweather=['djan1','wjan1','vjan1','vfeb1','vmar1','vapr1','vmay1',
'vjun1','vjul1','vaug1','vsep1','voct1','vnov1','vdec1','vjan2',
'vfeb2','vmar2','vapr2','vmay2','vjun2','vjul2','vaug2','vsep2',
'voct2','vnov2','wfeb1','wmar1','wapr1','wmay1','wjun1','wjul1',
'waug1','wsep1','woct1','wnov1','wdec1','wjan2','wfeb2','wmar2',
'wapr2','wmay2','wjun2','wjul2','waug2','wsep2','woct2','wnov2',
'wdec2','dfeb1','dmar1','dapr1','dmay1','djun1','djul1','daug1',
'dsep1','doct1','dnov1','ddec1','djan2','dfeb2','dmar2','dapr2',
'dmay2','djun2','djul2','daug2','dsep2','doct2','dnov2','ddec2']
weather =['dry','wet','vwet']
seasontemp=['wt','spt','sut','ft']
months=['jan1','feb1','mar1','apr1','may1','jun1','jul1','aug1','sep1','oct1','nov1','dec1',
        'jan2','feb2','mar2','apr2','may2','jun2','jul2','aug2','sep2','oct2','nov2','dec2']

# %%
features=seasons+seasonweather+seasontemp+months+weather+['holiday','workingday','temp',
                                      'atemp','humidity','windspeed','temp2',
                                      'atemp2','winds2','hum2','logtimescale']

# %%
from pandas.stats.api import ols
i=0
list=[]
list_=[]
while i < 24:
    test1=testFrame[(testFrame.hour==i)]
    model= ols(y=test1['logcasual'], x=test1[features])
    model_= ols(y=test1['logrgstr'], x=test1[features])
    list.append(model.rmse)
    list_.append(model_.rmse)
    i += 1
pd.DataFrame([list,list_]).swapaxes(0,1)
# Out:
#            0         1
# 0   0.600377  0.356227
# 1   0.653725  0.424451
# 2   0.686598  0.467936
# 3   0.571806  0.405159
# 4   0.558655  0.396935
# 5   0.497804  0.367704
# 6   0.502474  0.369090
# 7   0.495868  0.308598
# 8   0.403550  0.282078
# 9   0.425388  0.254062
# 10  0.460329  0.199309
# 11  0.433482  0.202658
# 12  0.418941  0.209894
# 13  0.399917  0.177015
# 14  0.421522  0.189579
# 15  0.450027  0.183396
# 16  0.378930  0.166497
# 17  0.379559  0.188826
# 18  0.352814  0.209898
# 19  0.392251  0.205334
# 20  0.422253  0.211407
# 21  0.455262  0.239589
# 22  0.508035  0.256593
# 23  0.570381  0.351877

# %%
test2=testFrame[(testFrame.hour < 16) & (testFrame.hour>11)]
model= ols(y=test2['logrgstr'], x=test2[features])
model.beta
# Out:
# spring    0.511008
# summer    0.516727
# winter    0.208523
# fall      0.765686
# djan1     0.001864
# wjan1    -0.134415
# vjan1    -0.005881
# vfeb1     0.198619
# vmar1    -0.939830
# vapr1    -0.150934
# vmay1     0.364444
# vjun1     0.141252
# vjul1    -0.172377
# vaug1     0.286509
# vsep1    -0.466205
# ...
# dry             0.783818
# wet             0.767502
# vwet            0.450624
# holiday        -0.109885
# workingday     -0.476911
# temp            0.060768
# atemp           0.013905
# humidity        0.014316
# windspeed       0.002542
# temp2          -0.000960
# atemp2         -0.000488
# winds2         -0.000160
# hum2           -0.000179
# logtimescale    0.053831
# intercept       2.001944
# Length: 118, dtype: float64

# %%
def hourCoef(h,label):
    return ols(y=testFrame[(testFrame.hour==h)][label],
                                       x=testFrame[(testFrame.hour==h)][features]).beta
def regsum(series, df):
    s=series['intercept']
    for x in features:
        s += series[x]*df[x]
    return s

j=0
coefficientsC=[]
coefficientsR=[]
while j<24:
    coefficientsC.append(hourCoef(j,'logcasual'))
    coefficientsR.append(hourCoef(j,'logrgstr'))
    j+=1

# %%
for n in [12,13,14,15]:
    coefficientsC[n]=ols(y=test2['logcasual'], x=test2[features]).beta
    coefficientsR[n]=ols(y=test2['logrgstr'], x=test2[features]).beta

# %%
test1=testFrame[(testFrame.hour==8)]
model= ols(y=test1['logcasual'], x=test1[features])
model
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <spring> + <summer> + <winter> + <fall> + <djan1> + <wjan1>
#              + <vjan1> + <vfeb1> + <vmar1> + <vapr1> + <vmay1> + <vjun1> + <vjul1>
#              + <vaug1> + <vsep1> + <voct1> + <vnov1> + <vdec1> + <vjan2> + <vfeb2>
#              + <vmar2> + <vapr2> + <vmay2> + <vjun2> + <vjul2> + <vaug2> + <vsep2>
#              + <voct2> + <vnov2> + <wfeb1> + <wmar1> + <wapr1> + <wmay1> + <wjun1>
#              + <wjul1> + <waug1> + <wsep1> + <woct1> + <wnov1> + <wdec1>
#              + <wjan2> + <wfeb2> + <wmar2> + <wapr2> + <wmay2> + <wjun2> + <wjul2>
#              + <waug2> + <wsep2> + <woct2> + <wnov2> + <wdec2> + <dfeb1> + <dmar1>
#              + <dapr1> + <dmay1> + <djun1> + <djul1> + <daug1> + <dsep1> + <doct1>
#              + <dnov1> + <ddec1> + <djan2> + <dfeb2> + <dmar2> + <dapr2> + <dmay2>
#              + <djun2> + <djul2> + <daug2> + <dsep2> + <doct2> + <dnov2>
# ...

# %%
resultFrame=testFrame
resultFrame= resultFrame.reset_index()
resultFrame['impulogrgst']=resultFrame.apply(lambda x: regsum(coefficientsR[x['hour']],x[features]) ,axis=1)
resultFrame['impulogcas']=resultFrame.apply(lambda x: regsum(coefficientsC[x['hour']],x[features]) ,axis=1)
resultFrame['impucount']=resultFrame.impulogcas.apply(lambda x: math.exp(x))+ resultFrame.impulogrgst.apply(lambda x: math.exp(x))-2

# %%
resultFrame['impulogcount']=resultFrame.impucount.apply(lambda x: math.log(x+1.0))
resultFrame[['impulogcas','logcasual','impulogrgst','logrgstr','count', 'impucount']].corr()
# Out:
#              impulogcas  logcasual  impulogrgst  logrgstr     count  impucount
# impulogcas     1.000000   0.945155     0.825844  0.805451  0.742707   0.765034
# logcasual      0.945155   1.000000     0.780550  0.787230  0.740363   0.723099
# impulogrgst    0.825844   0.780550     1.000000  0.975307  0.795573   0.822116
# logrgstr       0.805451   0.787230     0.975307  1.000000  0.812142   0.803611
# count          0.742707   0.740363     0.795573  0.812142  1.000000   0.963120
# impucount      0.765034   0.723099     0.822116  0.803611  0.963120   1.000000

# %%
sum((resultFrame.count-resultFrame.logc)**2)/10886
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-284-b6072ff0996b> in <module>()
# ----> 1 sum((resultFrame.count-resultFrame.logc)**2)/10886
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'logc'

# %%
resultFrame=pd.read_csv('bike share/test.csv')
resultFrame.datetime=resultFrame.datetime.apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
resultFrame['logtimescale']=resultFrame.datetime.apply(lambda x: math.log((x-datetime.datetime(2010,12,31,23,0,0)).total_seconds()))
resultFrame=resultFrame.set_index('datetime')

resultFrame['temp2']= resultFrame.temp**2
resultFrame['atemp2'] = resultFrame.atemp**2
resultFrame['winds2'] =resultFrame.windspeed**2
resultFrame['hour'] = resultFrame.index.hour
resultFrame['month'] = resultFrame.index.month
resultFrame['year'] = resultFrame.index.year
resultFrame['hum2']=resultFrame.humidity**2
resultFrame['winter']=resultFrame.season.apply(lambda x: 1 if x==1 else 0)
resultFrame['spring']=resultFrame.season.apply(lambda x: 1 if x==2 else 0)
resultFrame['summer']=resultFrame.season.apply(lambda x: 1 if x==3 else 0)
resultFrame['fall']=resultFrame.season.apply(lambda x: 1 if x==4 else 0)
resultFrame['dry']=resultFrame.weather.apply(lambda x: 1 if x==1 else 0)
resultFrame['wet']=resultFrame.weather.apply(lambda x: 1 if x==2 else 0)
resultFrame['vwet']=resultFrame.weather.apply(lambda x: 1 if x==3 else 0)
resultFrame['jan1']=resultFrame.apply(lambda x: 1 if x.month==1 and x.year==2011 else 0, axis=1)
resultFrame['feb1']=resultFrame.apply(lambda x: 1 if x.month==2 and x.year==2011 else 0, axis=1)
resultFrame['mar1']=resultFrame.apply(lambda x: 1 if x.month==3 and x.year==2011 else 0, axis=1)
resultFrame['apr1']=resultFrame.apply(lambda x: 1 if x.month==4 and x.year==2011 else 0, axis=1)
resultFrame['may1']=resultFrame.apply(lambda x: 1 if x.month==5 and x.year==2011 else 0, axis=1)
resultFrame['jun1']=resultFrame.apply(lambda x: 1 if x.month==6 and x.year==2011 else 0, axis=1)
resultFrame['jul1']=resultFrame.apply(lambda x: 1 if x.month==7 and x.year==2011 else 0, axis=1)
resultFrame['aug1']=resultFrame.apply(lambda x: 1 if x.month==8 and x.year==2011 else 0, axis=1)
resultFrame['sep1']=resultFrame.apply(lambda x: 1 if x.month==9 and x.year==2011 else 0, axis=1)
resultFrame['oct1']=resultFrame.apply(lambda x: 1 if x.month==10 and x.year==2011 else 0, axis=1)
resultFrame['nov1']=resultFrame.apply(lambda x: 1 if x.month==11 and x.year==2011 else 0, axis=1)
resultFrame['dec1']=resultFrame.apply(lambda x: 1 if x.month==12 and x.year==2011 else 0, axis=1)
resultFrame['jan2']=resultFrame.apply(lambda x: 1 if x.month==1 and x.year==2012 else 0, axis=1)
resultFrame['feb2']=resultFrame.apply(lambda x: 1 if x.month==2 and x.year==2012 else 0, axis=1)
resultFrame['mar2']=resultFrame.apply(lambda x: 1 if x.month==3 and x.year==2012 else 0, axis=1)
resultFrame['apr2']=resultFrame.apply(lambda x: 1 if x.month==4 and x.year==2012 else 0, axis=1)
resultFrame['may2']=resultFrame.apply(lambda x: 1 if x.month==5 and x.year==2012 else 0, axis=1)
resultFrame['jun2']=resultFrame.apply(lambda x: 1 if x.month==6 and x.year==2012 else 0, axis=1)
resultFrame['jul2']=resultFrame.apply(lambda x: 1 if x.month==7 and x.year==2012 else 0, axis=1)
resultFrame['aug2']=resultFrame.apply(lambda x: 1 if x.month==8 and x.year==2012 else 0, axis=1)
resultFrame['sep2']=resultFrame.apply(lambda x: 1 if x.month==9 and x.year==2012 else 0, axis=1)
resultFrame['oct2']=resultFrame.apply(lambda x: 1 if x.month==10 and x.year==2012 else 0, axis=1)
resultFrame['nov2']=resultFrame.apply(lambda x: 1 if x.month==11 and x.year==2012 else 0, axis=1)
resultFrame['dec2']=resultFrame.apply(lambda x: 1 if x.month==12 and x.year==2012 else 0, axis=1)
resultFrame['djan1']=resultFrame['jan1']*resultFrame['dry']
resultFrame['dfeb1']=resultFrame['feb1']*resultFrame['dry']
resultFrame['dmar1']=resultFrame['mar1']*resultFrame['dry']
resultFrame['dapr1']=resultFrame['apr1']*resultFrame['dry']
resultFrame['dmay1']=resultFrame['may1']*resultFrame['dry']
resultFrame['djun1']=resultFrame['jun1']*resultFrame['dry']
resultFrame['djul1']=resultFrame['jul1']*resultFrame['dry']
resultFrame['daug1']=resultFrame['aug1']*resultFrame['dry']
resultFrame['dsep1']=resultFrame['sep1']*resultFrame['dry']
resultFrame['doct1']=resultFrame['oct1']*resultFrame['dry']
resultFrame['dnov1']=resultFrame['nov1']*resultFrame['dry']
resultFrame['ddec1']=resultFrame['dec1']*resultFrame['dry']
resultFrame['djan2']=resultFrame['jan2']*resultFrame['dry']
resultFrame['dfeb2']=resultFrame['feb2']*resultFrame['dry']
resultFrame['dmar2']=resultFrame['mar2']*resultFrame['dry']
resultFrame['dapr2']=resultFrame['apr2']*resultFrame['dry']
resultFrame['dmay2']=resultFrame['may2']*resultFrame['dry']
resultFrame['djun2']=resultFrame['jun2']*resultFrame['dry']
resultFrame['djul2']=resultFrame['jul2']*resultFrame['dry']
resultFrame['daug2']=resultFrame['aug2']*resultFrame['dry']
resultFrame['dsep2']=resultFrame['sep2']*resultFrame['dry']
resultFrame['doct2']=resultFrame['oct2']*resultFrame['dry']
resultFrame['dnov2']=resultFrame['nov2']*resultFrame['dry']
resultFrame['ddec2']=resultFrame['dec2']*resultFrame['dry']
resultFrame['wjan1']=resultFrame['jan1']*resultFrame['wet']
resultFrame['wfeb1']=resultFrame['feb1']*resultFrame['wet']
resultFrame['wmar1']=resultFrame['mar1']*resultFrame['wet']
resultFrame['wapr1']=resultFrame['apr1']*resultFrame['wet']
resultFrame['wmay1']=resultFrame['may1']*resultFrame['wet']
resultFrame['wjun1']=resultFrame['jun1']*resultFrame['wet']
resultFrame['wjul1']=resultFrame['jul1']*resultFrame['wet']
resultFrame['waug1']=resultFrame['aug1']*resultFrame['wet']
resultFrame['wsep1']=resultFrame['sep1']*resultFrame['wet']
resultFrame['woct1']=resultFrame['oct1']*resultFrame['wet']
resultFrame['wnov1']=resultFrame['nov1']*resultFrame['wet']
resultFrame['wdec1']=resultFrame['dec1']*resultFrame['wet']
resultFrame['wjan2']=resultFrame['jan2']*resultFrame['wet']
resultFrame['wfeb2']=resultFrame['feb2']*resultFrame['wet']
resultFrame['wmar2']=resultFrame['mar2']*resultFrame['wet']
resultFrame['wapr2']=resultFrame['apr2']*resultFrame['wet']
resultFrame['wmay2']=resultFrame['may2']*resultFrame['wet']
resultFrame['wjun2']=resultFrame['jun2']*resultFrame['wet']
resultFrame['wjul2']=resultFrame['jul2']*resultFrame['wet']
resultFrame['waug2']=resultFrame['aug2']*resultFrame['wet']
resultFrame['wsep2']=resultFrame['sep2']*resultFrame['wet']
resultFrame['woct2']=resultFrame['oct2']*resultFrame['wet']
resultFrame['wnov2']=resultFrame['nov2']*resultFrame['wet']
resultFrame['wdec2']=resultFrame['dec2']*resultFrame['wet']
resultFrame['vjan1']=resultFrame['jan1']*resultFrame['vwet']
resultFrame['vfeb1']=resultFrame['feb1']*resultFrame['vwet']
resultFrame['vmar1']=resultFrame['mar1']*resultFrame['vwet']
resultFrame['vapr1']=resultFrame['apr1']*resultFrame['vwet']
resultFrame['vmay1']=resultFrame['may1']*resultFrame['vwet']
resultFrame['vjun1']=resultFrame['jun1']*resultFrame['vwet']
resultFrame['vjul1']=resultFrame['jul1']*resultFrame['vwet']
resultFrame['vaug1']=resultFrame['aug1']*resultFrame['vwet']
resultFrame['vsep1']=resultFrame['sep1']*resultFrame['vwet']
resultFrame['voct1']=resultFrame['oct1']*resultFrame['vwet']
resultFrame['vnov1']=resultFrame['nov1']*resultFrame['vwet']
resultFrame['vdec1']=resultFrame['dec1']*resultFrame['vwet']
resultFrame['vjan2']=resultFrame['jan2']*resultFrame['vwet']
resultFrame['vfeb2']=resultFrame['feb2']*resultFrame['vwet']
resultFrame['vmar2']=resultFrame['mar2']*resultFrame['vwet']
resultFrame['vapr2']=resultFrame['apr2']*resultFrame['vwet']
resultFrame['vmay2']=resultFrame['may2']*resultFrame['vwet']
resultFrame['vjun2']=resultFrame['jun2']*resultFrame['vwet']
resultFrame['vjul2']=resultFrame['jul2']*resultFrame['vwet']
resultFrame['vaug2']=resultFrame['aug2']*resultFrame['vwet']
resultFrame['vsep2']=resultFrame['sep2']*resultFrame['vwet']
resultFrame['voct2']=resultFrame['oct2']*resultFrame['vwet']
resultFrame['vnov2']=resultFrame['nov2']*resultFrame['vwet']
resultFrame['vdec2']=resultFrame['dec2']*resultFrame['vwet']
resultFrame['wt']=resultFrame.winter*resultFrame.atemp
resultFrame['spt']=resultFrame.spring*resultFrame.atemp
resultFrame['sut']=resultFrame.summer*resultFrame.atemp
resultFrame['ft']=resultFrame.fall*resultFrame.atemp
resultFrame['logtimescale2']=resultFrame.logtimescale**2
resultFrame= resultFrame.reset_index()
resultFrame['impulogrgst']=resultFrame.apply(lambda x: ridgesum(coefficientsR[x['hour']],x[features]) ,axis=1)
resultFrame['impulogcas']=resultFrame.apply(lambda x: ridgesum(coefficientsC[x['hour']],x[features]) ,axis=1)

# %%
resultFrame['impucount']=resultFrame.impulogcas.apply(lambda x: math.exp(x))+ resultFrame.impulogrgst.apply(lambda x: math.exp(x))-2
resultFrame.rename(columns={'impucount':'count'})[['datetime','count']].set_index('datetime').to_csv('bike share/submission11.csv')

# %%
resultFrame
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5    2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6    2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7    2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8    2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9    2011-01-20 09:00:00       1        0           1        2   9.84  11.365
# 10   2011-01-20 10:00:00       1        0           1        1  10.66  11.365
# ...

# %%
(-math.log(0.))**0.5
# Out:
# 1.8725805449485964

# %%
def hourRCoef(h,label):
    regression=linear_model.Ridge(alpha=0.0)
    regression.fit(testFrame[(testFrame.hour==h)][features].as_matrix(),
                     testFrame[(testFrame.hour==h)][label])
    return regression.coef_
def ridgesum(series, df):
    s=series[-1]
    i=0
    while i<len(features):
        s += series[i]*df[features[i]]
        i +=1
    return s

# %%
j=0
coefficientsC=[]
coefficientsR=[]
while j<24:
    coefficientsC.append(hourRCoef(j,'logcasual'))
    coefficientsR.append(hourRCoef(j,'logrgstr'))
    j+=1

# %%
# Out:
# [array([ -4.68612350e+10,  -1.38365786e+10,  -8.02361429e+10,
#          -9.15469502e+10,   6.31607460e+10,   1.25775698e+11,
#           7.37920884e+10,   3.91545020e+10,   1.18566947e+11,
#          -9.60402086e+10,  -1.07035793e+11,  -5.23074450e+10,
#          -6.36591070e+10,  -1.08072357e+11,  -1.42712588e+10,
#          -3.21032460e+10,  -1.69033657e+11,  -2.40283263e+10,
#           3.54415168e+09,  -2.19476000e+10,   5.29827944e+10,
#           1.19486199e+11,  -9.61299271e+08,   7.52326537e+10,
#          -1.00704636e+11,   5.71300323e+10,   1.26105516e+11,
#          -2.40924563e+11,  -4.90636177e+10,   9.11381114e+10,
#           1.52340011e+11,  -4.40565992e+10,  -5.50521832e+10,
#           1.53974121e+10,  -1.16754976e+10,  -5.60887480e+10,
#           3.77123506e+10,   1.98803634e+10,   8.53372350e+09,
#           2.79552831e+10,   5.55277611e+10,   3.00360094e+10,
#           1.04966404e+11,   4.56277008e+10,   5.10223101e+10,
# ...

# %%
for n in [12,13,14,15]:
    regression1=linear_model.Ridge(alpha=0.1)
    regression.fit(testFrame[(testFrame.hour==h)][features].values,
                     testFrame[(testFrame.hour==h)][label])
    coefficientsC[n]=regression1.coef_
    coefficientsR[n]=regression2.coef_
# Out:
# spring   -3.804682e-01
# summer   -3.347386e-01
# winter    9.161044e-02
# fall     -1.123682e-01
# djan1    -3.260620e-02
# wjan1     1.366608e-01
# vjan1     5.170613e-02
# vfeb1    -1.831820e-01
# vmar1     3.807017e-14
# vapr1    -3.449701e-01
# vmay1     1.743610e-01
# vjun1     7.770047e-13
# vjul1     9.065510e-02
# vaug1    -3.341009e-01
# vsep1    -4.367715e-01
# ...
# dry            -0.221889
# wet            -0.266622
# vwet           -0.247454
# holiday        -0.141267
# workingday     -0.629678
# temp            0.070586
# atemp           0.005194
# humidity        0.005716
# windspeed       0.009876
# temp2          -0.002234
# atemp2          0.000530
# winds2         -0.000228
# hum2           -0.000026
# logtimescale    0.055576
# intercept      -0.735964
# Length: 118, dtype: float64
